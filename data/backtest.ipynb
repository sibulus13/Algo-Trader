# %%
from sklearn.preprocessing import maxabs_scale
import numpy as np
import pandas as pd
import os
from joblib import load

def preprocessing(input, output):
    # TODO this is for the non optimal dataset stored with unnamed: 0 index
    input.dropna(inplace=True, axis=1)
    input = input.set_index('open').drop(columns=['Unnamed: 0'])
    print(input.columns)
    print(input.shape)
    print(input.head(1))
    input = input.values
    print(input[0])
    normalized_input = maxabs_scale(input, axis=0)
    # normalized_input = input / input.max(axis=0)
    output_h = output['highest_in_5_days'].values
    output_l = output['lowest_in_5_days'].values
    return input, output_l, output_h


def load_model(sym='AAPL',
               model_type='DecisionTreeRegressor',
               output_type='lows'):
    path = rf'D:\repo\stonks\data\dataset\{sym}\predictor_{output_type}_{model_type}.joblib'
    print(path)
    predictor_info = load(path)
    return predictor_info


DATASET_DIR = r'D:\repo\stonks\data\dataset'

def file_path(sym, type, file_type = 'csv', dir = DATASET_DIR):
    return os.path.join(dir, f'{sym}_{type}.{file_type}')

sym = 'AAPL'
input_df = pd.read_csv(file_path(sym, 'inputs'))
output_df = pd.read_csv(file_path(sym, 'outputs'))
input, output_l, output_h = preprocessing(input_df, output_df)
predictor_l = load_model(sym, 'DecisionTreeRegressor', 'lows')
predictor_h = load_model(sym, 'DecisionTreeRegressor', 'highs')
# Out:
# Index(['high', 'low', 'close', 'volume', 'trade_count', 'vwap', 'volume_adi',
#        'volume_obv', 'volume_cmf', 'volume_fi', 'volume_em', 'volume_sma_em',
#        'volume_vpt', 'volume_vwap', 'volume_nvi', 'volatility_bbm',
#        'volatility_bbh', 'volatility_bbl', 'volatility_bbw', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kcw', 'volatility_kchi', 'volatility_kcli',
#        'volatility_dcl', 'volatility_dch', 'volatility_dcm', 'volatility_dcw',
#        'volatility_atr', 'volatility_ui', 'trend_macd', 'trend_macd_signal',
#        'trend_macd_diff', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast',
#        'trend_ema_slow', 'trend_trix', 'trend_mass_index', 'trend_dpo',
#        'trend_kst', 'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_adx', 'trend_adx_pos', 'trend_adx_neg',
#        'trend_visual_ichimoku_b', 'trend_aroon_up', 'trend_aroon_down',
#        'trend_aroon_ind', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_tsi',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr'],
#       dtype='object')
# (1277361, 73)
#         high    low  close  volume  trade_count        vwap  volume_adi  \
# open
# 118.8  118.8  118.8  118.8   622.0          6.0  118.795338     10571.0
#
#        volume_obv  volume_cmf  volume_fi  ...  momentum_ppo  \
# open                                      ...
# 118.8     12338.0    0.184498   1.364871  ...       0.00573
#
#        momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  \
# open
# 118.8              0.01943            -0.0137       5.06626
#
#        momentum_pvo_signal  momentum_pvo_hist  momentum_kama  others_dr  \
# open
# 118.8             9.211953          -4.145693     118.872703        0.0
#
#        others_dlr  others_cr
# open
# 118.8         0.0  -0.117706
#
# [1 rows x 73 columns]
# [ 1.18800000e+02  1.18800000e+02  1.18800000e+02  6.22000000e+02
#   6.00000000e+00  1.18795338e+02  1.05710000e+04  1.23380000e+04
#   1.84498480e-01  1.36487117e+00  0.00000000e+00  2.50164245e+01
#   1.01035615e-01  1.18889101e+02  1.00000453e+03  1.18850000e+02
#   1.18970333e+02  1.18729667e+02  2.02495367e-01  0.00000000e+00
#   0.00000000e+00  1.18851667e+02  1.18866667e+02  1.18836667e+02
#   2.52415476e-02  0.00000000e+00  1.00000000e+00  1.18770000e+02
#   1.18990000e+02  1.18880000e+02  1.85107278e-01  3.36156232e-02
#   1.12282839e-01  6.80892542e-03  2.30881619e-02 -1.62792365e-02
#   1.18859167e+02  1.18838846e+02  1.18832161e+02  1.18825352e+02
#   3.82296743e-03  2.88889325e+01  5.00000000e-02  1.10926776e+00
#  -1.40007664e+00  2.50934440e+00  1.18840000e+02  1.18875000e+02
#   1.18857500e+02  1.18745000e+02  1.87118493e+01  3.96430833e+01
#   3.64194370e+01  1.18720000e+02  5.20000000e+01  8.00000000e+00
#   4.40000000e+01  0.00000000e+00  0.00000000e+00  4.70291856e+01
#   3.87949894e+00 -7.05882353e-04 -1.59677284e-01  5.73019587e-03
#   1.94303197e-02 -1.37001238e-02  5.06625967e+00  9.21195281e+00
#  -4.14569314e+00  1.18872703e+02  0.00000000e+00  0.00000000e+00
#  -1.17706407e-01]
# D:\repo\stonks\data\dataset\AAPL\predictor_lows_DecisionTreeRegressor.joblib
# D:\repo\stonks\data\dataset\AAPL\predictor_highs_DecisionTreeRegressor.joblib

# %%
def run_back_test(X,
                  predictor_h,
                  predictor_l,
                  gain_ratio=1.5,
                  min_gain_ratio=1.1,
                  max_loss_ratio=0.9,
                  buy_threshold=0):
    '''
    Tests prediction model based on gain factor and safety margin
    Assumes using bracket order
    gain_ratio: gain factor to sell
    min_gain_ratio: minimum gain factor to buy
    max_loss_ratio: maximum loss factor to buy
    '''
    brought = False
    buy_counter = 0
    brought_prices = []
    brought_index = []
    sold_prices = []
    sold_index = []
    brought_margins = []
    gains = []

    for index, row in enumerate(X):
        # 0=open, 1=high, 2=low, 3=close, 4=volume
        closed_price = row[2]
        if brought:
            # Stop Loss
            stop_loss = closed_price <= (brought_prices[-1] *
                                         brought_margins[-1][0])
            take_profit = closed_price >= (brought_prices[-1] *
                                           brought_margins[-1][1])
            if stop_loss or take_profit:
                # print('stop_loss', stop_loss, 'take_profit', take_profit, 'closed_price', closed_price, 'brought_price', brought_prices[-1], 'gain', closed_price/brought_prices[-1])
                sold_prices.append(closed_price)
                sold_index.append(index)
                gains.append(sold_prices[-1] / brought_prices[-1])
                brought = False
                # print('sold @ ', closed_price, 'brought @ ', brought_prices[-1], 'gain = ', closed_price/brought_prices[-1])
            else:
                continue

        input = row.reshape(1, -1)
        low_prediction = predictor_l['model'].predict(input)[0]/100
        high_prediction = predictor_h['model'].predict(input)[0]/100
        gain = round(high_prediction / low_prediction, 2)
        gain_ratio_achieved = gain >= gain_ratio
        min_gain_ratio_achieved = high_prediction >= min_gain_ratio
        max_loss_ratio_overcomed = low_prediction >= max_loss_ratio
        # print('gain', gain, 'gain_ratio_achieved', low_prediction, high_prediction)
        if not brought:
            buy_counter += 1
            if gain_ratio_achieved and min_gain_ratio_achieved and max_loss_ratio_overcomed and buy_counter >= buy_threshold:
                brought = True
                # print('brought @ ', closed_price)
                brought_prices.append(closed_price)
                brought_index.append(index)
                brought_margins.append([low_prediction, high_prediction])
                buy_counter = 0
    gain = np.prod(gains)
    print('gain:', gain, 'gain_ratio:', gain_ratio, 'min_gain_ratio:', min_gain_ratio, 'max_loss_ratio:', max_loss_ratio)
    return brought_prices, sold_prices, brought_index, sold_index, brought_margins, gains, gain

backtests = []
for gain_ratio in [1]:
    # np.arange(1, 3, 0.1)
    for min_gain_ratio in np.arange(1, 2, 0.03):
        for max_loss_ratio in np.arange(0.9, 1.1, 0.03):            
            brought_prices, sold_prices, brought_index, sold_index, brought_margins, gains, gain = run_back_test(input,
                            predictor_h,
                            predictor_l,
                            gain_ratio=gain_ratio,
                            min_gain_ratio=min_gain_ratio,
                            max_loss_ratio=max_loss_ratio,
                            buy_threshold=0)
            score = {'gain_ratio': gain_ratio,
                     'min_gain_ratio': min_gain_ratio,
                     'max_loss_ratio': max_loss_ratio,
                     'gain': gain,
                     'brought_prices': brought_prices,
                     'sold_prices': sold_prices,
                     'brought_index': brought_index,
                     'sold_index': sold_index,
                     'brought_margins': brought_margins,
                     'gains': gains   
                     }
            backtests.append(score)
            
# Takes 1500 seconds to run triple for loop
# 1min/loop * 50^2 loops = 2500min = 41.6 hours
# 375min for 238 loops = 1.57min/loop
# Out:
# gain: 1.3181345582053077 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 0.9
# gain: 1.3883038049550909 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 0.93
# gain: 1.6429296218537326 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 0.9600000000000001
# gain: 1.3770932140242778 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 0.9900000000000001
# gain: 1.4895209471376523 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 1.02
# gain: 1.7016513031544087 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 1.0500000000000003
# gain: 1.6339678656978163 gain_ratio: 1 min_gain_ratio: 1.0 max_loss_ratio: 1.08
# gain: 1.1047942934568427 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 0.9
# gain: 1.1955581336702463 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 0.93
# gain: 1.5214741754099232 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 0.9600000000000001
# gain: 1.3893929395308573 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 0.9900000000000001
# gain: 1.4895209471376523 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 1.02
# gain: 1.7016513031544087 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 1.0500000000000003
# gain: 1.6339678656978163 gain_ratio: 1 min_gain_ratio: 1.03 max_loss_ratio: 1.08
# gain: 1.3083571049161629 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 0.9
# gain: 1.3083571049161629 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 0.93
# gain: 1.390186981160762 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 0.9600000000000001
# gain: 1.390186981160762 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 0.9900000000000001
# gain: 1.4726515798161186 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 1.02
# gain: 1.7016513031544087 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 1.0500000000000003
# gain: 1.6339678656978163 gain_ratio: 1 min_gain_ratio: 1.06 max_loss_ratio: 1.08
# gain: 1.4281984845383213 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 0.9
# gain: 1.4281984845383213 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 0.93
# gain: 1.4281984845383213 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 0.9600000000000001
# gain: 1.4281984845383213 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 0.9900000000000001
# gain: 1.4710406316405917 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 1.02
# gain: 1.669802654731357 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 1.0500000000000003
# gain: 1.6339678656978163 gain_ratio: 1 min_gain_ratio: 1.09 max_loss_ratio: 1.08
# gain: 1.6436611572340507 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 0.9
# gain: 1.6436611572340507 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 0.93
# gain: 1.6436611572340507 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 0.9600000000000001
# gain: 1.6436611572340507 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 0.9900000000000001
# gain: 1.685984350726256 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 1.02
# gain: 1.8001813914605214 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 1.0500000000000003
# gain: 1.680187535458947 gain_ratio: 1 min_gain_ratio: 1.12 max_loss_ratio: 1.08
# gain: 1.6982731419200279 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 0.9
# gain: 1.6982731419200279 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 0.93
# gain: 1.6982731419200279 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 0.9600000000000001
# gain: 1.6982731419200279 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 0.9900000000000001
# gain: 1.7010318256729515 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 1.02
# gain: 1.6767072690527893 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 1.0500000000000003
# gain: 1.6683260659512043 gain_ratio: 1 min_gain_ratio: 1.1500000000000001 max_loss_ratio: 1.08
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 0.9
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 0.93
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 0.9600000000000001
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 0.9900000000000001
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 1.02
# gain: 1.6357780687313306 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 1.0500000000000003
# gain: 1.6310280762828695 gain_ratio: 1 min_gain_ratio: 1.1800000000000002 max_loss_ratio: 1.08
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 0.9
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 0.93
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 0.9600000000000001
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 0.9900000000000001
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 1.02
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 1.0500000000000003
# gain: 1.4691084528246674 gain_ratio: 1 min_gain_ratio: 1.2100000000000002 max_loss_ratio: 1.08
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 0.9
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 0.93
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 0.9600000000000001
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 0.9900000000000001
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 1.02
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 1.0500000000000003
# gain: 1.3460706966143285 gain_ratio: 1 min_gain_ratio: 1.2400000000000002 max_loss_ratio: 1.08
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 0.9
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 0.93
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 0.9600000000000001
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 0.9900000000000001
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 1.02
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 1.0500000000000003
# gain: 1.507750311032774 gain_ratio: 1 min_gain_ratio: 1.2700000000000002 max_loss_ratio: 1.08
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 0.9
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 0.93
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 0.9600000000000001
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 0.9900000000000001
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 1.02
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 1.0500000000000003
# gain: 1.2667541855808457 gain_ratio: 1 min_gain_ratio: 1.3000000000000003 max_loss_ratio: 1.08
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 0.9
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 0.93
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 0.9600000000000001
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 0.9900000000000001
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 1.02
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 1.0500000000000003
# gain: 1.2807197788358144 gain_ratio: 1 min_gain_ratio: 1.3300000000000003 max_loss_ratio: 1.08
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 0.9
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 0.93
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 0.9600000000000001
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 0.9900000000000001
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 1.02
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 1.0500000000000003
# gain: 1.2806089396458171 gain_ratio: 1 min_gain_ratio: 1.3600000000000003 max_loss_ratio: 1.08
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 0.9
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 0.93
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 0.9600000000000001
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 0.9900000000000001
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 1.02
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 1.0500000000000003
# gain: 1.1501635687183531 gain_ratio: 1 min_gain_ratio: 1.3900000000000003 max_loss_ratio: 1.08
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 0.9
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 0.93
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 0.9600000000000001
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 0.9900000000000001
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 1.02
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 1.0500000000000003
# gain: 1.2186951718094936 gain_ratio: 1 min_gain_ratio: 1.4200000000000004 max_loss_ratio: 1.08
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 0.9
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 0.93
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 0.9600000000000001
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 0.9900000000000001
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 1.02
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 1.0500000000000003
# gain: 1.2027862342681226 gain_ratio: 1 min_gain_ratio: 1.4500000000000004 max_loss_ratio: 1.08
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 0.9
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 0.93
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 0.9600000000000001
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 0.9900000000000001
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 1.02
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 1.0500000000000003
# gain: 1.230735622122053 gain_ratio: 1 min_gain_ratio: 1.4800000000000004 max_loss_ratio: 1.08
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 0.9
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 0.93
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 0.9600000000000001
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 0.9900000000000001
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 1.02
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 1.0500000000000003
# gain: 1.0603207127302152 gain_ratio: 1 min_gain_ratio: 1.5100000000000005 max_loss_ratio: 1.08
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 0.9
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 0.93
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 0.9600000000000001
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 0.9900000000000001
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 1.02
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 1.0500000000000003
# gain: 0.9616123731042737 gain_ratio: 1 min_gain_ratio: 1.5400000000000005 max_loss_ratio: 1.08
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 0.9
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 0.93
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 0.9600000000000001
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 0.9900000000000001
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 1.02
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 1.0500000000000003
# gain: 0.9531474708407024 gain_ratio: 1 min_gain_ratio: 1.5700000000000005 max_loss_ratio: 1.08
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 0.9
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 0.93
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 0.9600000000000001
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 0.9900000000000001
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 1.02
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 1.0500000000000003
# gain: 1.0603681896776518 gain_ratio: 1 min_gain_ratio: 1.6000000000000005 max_loss_ratio: 1.08
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 0.9
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 0.93
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 0.9600000000000001
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 0.9900000000000001
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 1.02
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 1.0500000000000003
# gain: 1.1121120333863832 gain_ratio: 1 min_gain_ratio: 1.6300000000000006 max_loss_ratio: 1.08
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 0.9
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 0.93
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 0.9600000000000001
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 0.9900000000000001
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 1.02
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 1.0500000000000003
# gain: 1.1985285886419759 gain_ratio: 1 min_gain_ratio: 1.6600000000000006 max_loss_ratio: 1.08
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 0.9
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 0.93
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 0.9600000000000001
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 0.9900000000000001
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 1.02
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 1.0500000000000003
# gain: 1.1837119388340938 gain_ratio: 1 min_gain_ratio: 1.6900000000000006 max_loss_ratio: 1.08
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 0.9
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 0.93
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 0.9600000000000001
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 0.9900000000000001
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 1.02
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 1.0500000000000003
# gain: 1.1947880723474662 gain_ratio: 1 min_gain_ratio: 1.7200000000000006 max_loss_ratio: 1.08
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 0.9
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 0.93
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 0.9600000000000001
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 0.9900000000000001
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 1.02
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 1.0500000000000003
# gain: 1.2706377770266282 gain_ratio: 1 min_gain_ratio: 1.7500000000000007 max_loss_ratio: 1.08
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 0.9
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 0.93
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 0.9600000000000001
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 0.9900000000000001
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 1.02
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 1.0500000000000003
# gain: 0.8990929408550513 gain_ratio: 1 min_gain_ratio: 1.7800000000000007 max_loss_ratio: 1.08
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 0.9
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 0.93
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 0.9600000000000001
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 0.9900000000000001
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 1.02
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 1.0500000000000003
# gain: 0.9102458590354882 gain_ratio: 1 min_gain_ratio: 1.8100000000000007 max_loss_ratio: 1.08
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 0.9
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 0.93
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 0.9600000000000001
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 0.9900000000000001
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 1.02
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 1.0500000000000003
# gain: 0.7887325608741274 gain_ratio: 1 min_gain_ratio: 1.8400000000000007 max_loss_ratio: 1.08
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 0.9
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 0.93
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 0.9600000000000001
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 0.9900000000000001
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 1.02
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 1.0500000000000003
# gain: 0.8077868259993913 gain_ratio: 1 min_gain_ratio: 1.8700000000000008 max_loss_ratio: 1.08
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 0.9
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 0.93
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 0.9600000000000001
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 0.9900000000000001
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 1.02
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 1.0500000000000003
# gain: 0.7603489357193949 gain_ratio: 1 min_gain_ratio: 1.9000000000000008 max_loss_ratio: 1.08
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 0.9
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 0.93
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 0.9600000000000001
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 0.9900000000000001
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 1.02
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 1.0500000000000003
# gain: 0.7203163306527238 gain_ratio: 1 min_gain_ratio: 1.9300000000000008 max_loss_ratio: 1.08
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 0.9
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 0.93
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 0.9600000000000001
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 0.9900000000000001
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 1.02
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 1.0500000000000003
# gain: 0.7113749811773648 gain_ratio: 1 min_gain_ratio: 1.9600000000000009 max_loss_ratio: 1.08
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 0.9
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 0.93
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 0.9600000000000001
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 0.9900000000000001
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 1.02
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 1.0500000000000003
# gain: 0.6691036650417819 gain_ratio: 1 min_gain_ratio: 1.9900000000000009 max_loss_ratio: 1.08

# %%
print('num of scores:', len(backtests))
backtests_df = pd.DataFrame(backtests).sort_values('gain', ascending=False)
# print(backtests_df)
# backtests_df.to_csv(rf'D:\repo\stonks\data\dataset\{sym}\backtests.csv', index=False)
print(backtests_df.head(5)[['min_gain_ratio', 'max_loss_ratio', 'gain']])
best_gain = backtests_df.iloc[0]['gains']
print(type(best_gain), len(best_gain))
print(np.mean(best_gain))
print(np.prod(best_gain))
# Out:
# num of scores: 238
#     min_gain_ratio  max_loss_ratio      gain
# 33            1.12            1.05  1.800181
# 12            1.03            1.05  1.701651
# 5             1.00            1.05  1.701651
# 19            1.06            1.05  1.701651
# 39            1.15            1.02  1.701032
# <class 'list'> 1158706
# 1.0000013792073355
# 1.8001813914605214
